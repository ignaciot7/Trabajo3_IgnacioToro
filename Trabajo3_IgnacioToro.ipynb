# %%
from bs4 import BeautifulSoup

# %%
#Abriendo archivo index.html
with open(r'index.html', "r") as doc_html:
    page = BeautifulSoup(doc_html.read(), 'html.parser')

# %%
#Se revisa su contenido
print(f'page: \n{page.prettify()}')
# Out:
# page:
# <html>
#  <head>
#   <style>
#    table, th, td, h1, h2, p{border: 2px solid black;
#             border-collapse: collapse;}
#             body{background-color: blue;}
#             h1, h2, p, table{background-color: red;}
#   </style>
#  </head>
#  <br/>
#  <br/>
#  <body <div="">
#   <div>
#    <text align="center">
#     <h1>
#      Universidad de Chile clasifica a semifinales de Copa Chile
#     </h1>
#    </text>
#    <div>
#     <img align="left" alt="El Chorri" src="https://redgol.cl/_next/image?url=https%3A%2F%2Fredgol.cl%2F__export%2F1665704108729%2Fsites%2Fredgol%2Fimg%2F2022%2F10%2F13%2Fa_uno_1403493_crop1665704107562.jpg_1546398727.jpg&amp;w=1920&amp;q=75" width="500px"/>
#    </div>
#    <br/>
#    <div>
#     <h2>
#      Universidad de Chile elimina a la UC tras la reanudaciÃ³n del partido suspendido
#     </h2>
#     <p>
# ...

# %%
#PÁGINA FALABELLA
from bs4 import BeautifulSoup

#importar requests
import requests

#Abriendo página de falabella
url = 'https://www.falabella.com/falabella-cl/category/cat7090034/Tecnologia'

#Obtención de la página
page = requests.get(url)
print(f"Codigo: {page.status_code}")

page = BeautifulSoup(page.content, 'html.parser')
print(page.prettify())
# Out:
# Codigo: 200
# <!DOCTYPE html>
# <html lang="es">
#  <head>
#   <style>
#    body { margin: 0 } /* custom! */
#   </style>
#   <meta charset="utf-8" class="next-head"/>
#   <script class="next-head">
#    (function(w,d,s,l,i){w[l]=w[l]||[];
#             w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});
#             var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';
#             j.async=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;
#             f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-NJX6QWJ');
#   </script>
#   <script class="next-head" src="https://try.abtasty.com/c350da377600c0eccd33d8275e5910f5.js">
#   </script>
#   <script class="next-head" src="https://assets.contentstack.io/v3/assets/blt7c5c2f2f888a7cc3/blt146c74be2dd47717/627eaf0cbdec0b542e4eef40/vwo.js">
#   </script>
# ...

# %%
#Abriendo otra página web, para este caso se eligio Bold, página de una tienda de ropa urbana y deportiva
import requests

url = 'https://bold.cl/Bold/Accesorios/c/boldAccesorios'

#Obtención de la página
page = requests.get(url)
print(f"Codigo: {page.status_code}")
# Out:
# Codigo: 200

# %%
#Se lee la página
from bs4 import BeautifulSoup
page = BeautifulSoup(page.content, 'html.parser')
print(page.prettify())
# Out:
# <!DOCTYPE html>
# <html class="h-100" lang="en">
#  <head>
#   <title>
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8">
#    <base href="/"/>
#    <meta content="width=device-width, initial-scale=1" name="viewport">
#     <meta content="" name="title"/>
#     <meta content="" name="description"/>
#     <meta content="" name="keywords"/>
#     <meta content="index, follow" name="robots"/>
#     <meta content="6AcB0qf27FrqIiJFa0Z36INTfsCVi7pIgr5lMizaLT0" name="google-site-verification">
#      <meta content="https://api.cxl8rgz-articulos1-p1-public.model-t.cc.commerce.ondemand.com" name="occ-backend-base-url">
#       <script>
#        const hostname = window.location.hostname;
#     if (hostname.includes('belsport.cl')) {
#       document.title = "Belsport.cl | Tienda especializada de zapatillas";
# ...
